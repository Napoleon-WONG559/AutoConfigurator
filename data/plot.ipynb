# %%
import matplotlib.pyplot as plt

# %%
ypoints = [3, 8, 1, 10]
y1points = [4, 7, 4, 7]

plt.plot(ypoints, color = 'r')
plt.plot(y1points, color = 'b')

plt.plot(ypoints, label='First Line')
plt.plot(y1points, label='Second Line')

plt.legend()

plt.show()

# %%
attr_label_promptBERT=[
    0.7177570093457943,\
0.5894080996884735,\
0.47757009345794393,\
0.3902803738317756,\
0.3283489096573209,\
0.2835781041388518,\
0.25000000000000006,\
0.2222222222222222\
]

attr_label_PTBERT=[
    0.7196261682242989,\
0.5831775700934578,\
0.47102803738317756,\
0.38728971962616826,\
0.3264797507788162,\
0.28144192256341793,\
0.2485981308411215,\
0.2222222222222222
]

attr_label_MMPBERT=[
    0.6990654205607475,\
0.5869158878504672,\
0.47757009345794393,\
0.3910280373831775,\
0.32897196261682243,\
0.2819759679572763,\
0.24766355140186916,\
0.2222222222222222
]

attr_label_BERT=[
    0.622429906542056,\
0.57196261682243,\
0.4542056074766355,\
0.37383177570093457,\
0.3214953271028037,\
0.27930574098798394,\
0.24672897196261678,\
0.2222222222222222
]

attr_label_LSTM=[
    0.657943925233645,\
0.49470404984423677,\
0.383177570093458,\
0.32000000000000006,\
0.29657320872274145,\
0.2739652870493992,\
0.24813084112149533,\
0.2222222222222222
]

x=[(i+1) for i in range(len(attr_label_MMPBERT))]

plt.figure(figsize=(10, 15))

plt.plot(x,attr_label_promptBERT, color = 'Fuchsia')
plt.plot(x,attr_label_PTBERT, color = 'b')
plt.plot(x,attr_label_MMPBERT, color = 'chartreuse')
plt.plot(x,attr_label_BERT, color = 'cornflowerblue')
plt.plot(x,attr_label_LSTM, color = 'coral')

plt.plot(x,attr_label_promptBERT, label='Prompt BERT')
plt.plot(x, attr_label_PTBERT, label='Prompt Tuning BERT')
plt.plot(x, attr_label_MMPBERT, label='Multi-Mask Prompt BERT')
plt.plot(x, attr_label_BERT, label='BERT')
plt.plot(x, attr_label_LSTM, label='LSTM')

plt.xlabel('k value in @k')
plt.ylabel('F1 score for attribute of \'Screen\'')

plt.legend()

#plt.show()

plt.savefig("F1score_screen.pdf", format="pdf", bbox_inches="tight")

# %%
attr_label_promptBERT=[
    0.49719626168224296,\
0.5158878504672897,\
0.47850467289719617,\
0.4
]

attr_label_PTBERT=[
    0.4672897196261683,\
0.5034267912772586,\
0.48130841121495327,\
0.4
]

attr_label_MMPBERT=[
    0.4803738317757009,\
0.5171339563862928,\
0.466355140186916,\
0.4
]

attr_label_BERT=[
    0.44485981308411215,\
0.5084112149532711,\
0.48785046728971965,\
0.4
]

attr_label_LSTM=[
    0.39439252336448605,\
0.4074766355140187,\
0.4841121495327102,\
0.4
]

x=[(i+1) for i in range(len(attr_label_MMPBERT))]

plt.figure(figsize=(10, 15))

plt.plot(x,attr_label_promptBERT, color = 'Fuchsia')
plt.plot(x,attr_label_PTBERT, color = 'b')
plt.plot(x,attr_label_MMPBERT, color = 'chartreuse')
plt.plot(x,attr_label_BERT, color = 'cornflowerblue')
plt.plot(x,attr_label_LSTM, color = 'coral')

plt.plot(x,attr_label_promptBERT, label='Prompt BERT')
plt.plot(x, attr_label_PTBERT, label='Prompt Tuning BERT')
plt.plot(x, attr_label_MMPBERT, label='Multi-Mask Prompt BERT')
plt.plot(x, attr_label_BERT, label='BERT')
plt.plot(x, attr_label_LSTM, label='LSTM')

plt.xlabel('k value in @k')
plt.ylabel('F1 score for attribute of \'CPU\'')

plt.legend()

#plt.show()

plt.savefig("F1score_cpu.pdf", format="pdf", bbox_inches="tight")

# %%
attr_label_promptBERT=[
    0.6579439252336449,\
0.5545171339563862,\
0.4588785046728972,\
0.3865420560747663,\
0.3302180685358255,\
0.2857142857142857,\
0.25000000000000006
]

attr_label_PTBERT=[
    0.6504672897196262,\
0.5520249221183802,\
0.4570093457943925,\
0.3850467289719626,\
0.3320872274143302,\
0.28518024032042716,\
0.25000000000000006
]

attr_label_MMPBERT=[
    0.6280373831775702,\
0.540809968847352,\
0.4542056074766355,\
0.38130841121495324,\
0.3308411214953271,\
0.28518024032042716,\
0.25000000000000006
]

attr_label_BERT=[
    0.6299065420560748,\
0.5482866043613708,\
0.4495327102803738,\
0.37831775700934583,\
0.33084112149532713,\
0.28464619492656873,\
0.24999999999999994
]

attr_label_LSTM=[
    0.15700934579439252,\
0.5345794392523363,\
0.4233644859813084,\
0.36560747663551396,\
0.31900311526479747,\
0.28251001335113485,\
0.25
]

x=[(i+1) for i in range(len(attr_label_MMPBERT))]

plt.figure(figsize=(10, 15))

plt.plot(x,attr_label_promptBERT, color = 'Fuchsia')
plt.plot(x,attr_label_PTBERT, color = 'b')
plt.plot(x,attr_label_MMPBERT, color = 'chartreuse')
plt.plot(x,attr_label_BERT, color = 'cornflowerblue')
plt.plot(x,attr_label_LSTM, color = 'coral')

plt.plot(x,attr_label_promptBERT, label='Prompt BERT')
plt.plot(x, attr_label_PTBERT, label='Prompt Tuning BERT')
plt.plot(x, attr_label_MMPBERT, label='Multi-Mask Prompt BERT')
plt.plot(x, attr_label_BERT, label='BERT')
plt.plot(x, attr_label_LSTM, label='LSTM')

plt.xlabel('k value in @k')
plt.ylabel('F1 score for attribute of \'RAM\'')

plt.legend()

#plt.show()

plt.savefig("F1score_ram.pdf", format="pdf", bbox_inches="tight")

# %%
attr_label_promptBERT=[
    0.5887850467289719,\
0.5171339563862929,\
0.4299065420560747,\
0.3685981308411215,\
0.31900311526479747,\
0.2857142857142857
]

attr_label_PTBERT=[
    0.5663551401869159,\
0.5096573208722741,\
0.42710280373831777,\
0.3693457943925234,\
0.3227414330218069,\
0.2857142857142857
]

attr_label_MMPBERT=[
    0.5457943925233645,\
0.5046728971962618,\
0.4392523364485981,\
0.37009345794392523,\
0.3252336448598131,\
0.2857142857142857
]

attr_label_BERT=[
    0.4616822429906542,\
0.42367601246105924,\
0.3757009345794393,\
0.33121495327102807,\
0.31214953271028034,\
0.28571428571428575
]

attr_label_LSTM=[
    0.633644859813084,\
0.46853582554517137,\
0.40186915887850466,\
0.3558878504672897,\
0.3208722741433022,\
0.2857142857142857
]

x=[(i+1) for i in range(len(attr_label_MMPBERT))]

plt.figure(figsize=(10, 15))

plt.plot(x,attr_label_promptBERT, color = 'Fuchsia')
plt.plot(x,attr_label_PTBERT, color = 'b')
plt.plot(x,attr_label_MMPBERT, color = 'chartreuse')
plt.plot(x,attr_label_BERT, color = 'cornflowerblue')
plt.plot(x,attr_label_LSTM, color = 'coral')

plt.plot(x,attr_label_promptBERT, label='Prompt BERT')
plt.plot(x, attr_label_PTBERT, label='Prompt Tuning BERT')
plt.plot(x, attr_label_MMPBERT, label='Multi-Mask Prompt BERT')
plt.plot(x, attr_label_BERT, label='BERT')
plt.plot(x, attr_label_LSTM, label='LSTM')

plt.xlabel('k value in @k')
plt.ylabel('F1 score for attribute of \'hard disk\'')

plt.legend()

#plt.show()

plt.savefig("F1score_hardisk.pdf", format="pdf", bbox_inches="tight")

# %%
attr_label_promptBERT=[
    0.5401869158878505,\
0.5258566978193148,\
0.46261682242990654,\
0.3917757009345795,\
0.33333333333333337
]

attr_label_PTBERT=[
    0.5383177570093458,\
0.5171339563862928,\
0.4635514018691589,\
0.3955140186915888,\
0.33333333333333337
]

attr_label_MMPBERT=[
    0.5233644859813085,\
0.4934579439252337,\
0.4457943925233645,\
0.3887850467289719,\
0.33333333333333337
]

attr_label_BERT=[
    0.5364485981308411,\
0.5121495327102804,\
0.4514018691588785,\
0.3917757009345795,\
0.33333333333333337
]

attr_label_LSTM=[
    0.43551401869158873,\
0.39501557632398754,\
0.4308411214953271,\
0.39925233644859814,\
0.33333333333333337
]

x=[(i+1) for i in range(len(attr_label_MMPBERT))]

plt.figure(figsize=(10, 15))

plt.plot(x,attr_label_promptBERT, color = 'Fuchsia')
plt.plot(x,attr_label_PTBERT, color = 'b')
plt.plot(x,attr_label_MMPBERT, color = 'chartreuse')
plt.plot(x,attr_label_BERT, color = 'cornflowerblue')
plt.plot(x,attr_label_LSTM, color = 'coral')

plt.plot(x,attr_label_promptBERT, label='Prompt BERT')
plt.plot(x, attr_label_PTBERT, label='Prompt Tuning BERT')
plt.plot(x, attr_label_MMPBERT, label='Multi-Mask Prompt BERT')
plt.plot(x, attr_label_BERT, label='BERT')
plt.plot(x, attr_label_LSTM, label='LSTM')

plt.xlabel('k value in @k')
plt.ylabel('F1 score for attribute of \'graphic card\'')

plt.legend()

#plt.show()

plt.savefig("F1score_graphic.pdf", format="pdf", bbox_inches="tight")
